# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import warnings
from scipy import stats
warnings.simplefilter(action='ignore')

# %%
data = pd.read_excel('data/DEFAULT_AVG_TIME.xls')
data.shape
# Out:
# (18309, 31)

# %%
data[['DaysInCollection_one', 'bad', 'maxdelay_one', 'delays_one']]
# Out:
#        DaysInCollection_one  bad  maxdelay_one  delays_one
# 0                        17    0            27           0
# 1                        18    0            16           0
# 2                         4    0            16           0
# 3                        32    1            29           0
# 4                        32    1            48           1
# ...                     ...  ...           ...         ...
# 18304                     2    0             3           0
# 18305                    15    0             0           0
# 18306                     1    0             0           0
# 18307                     4    0             0           0
# 18308                     3    0            15           0
#
# [18309 rows x 4 columns]

# %%
data[data['maxdelay_one']>338][['DaysInCollection_one', 'bad', 'maxdelay_one', 'delays_one']]
# Out:
#        DaysInCollection_one  bad  maxdelay_one  delays_one
# 16693                    32    1           339           1
# 16778                    32    1           339           1
# 16863                    18    0           339           1

# %%
data[(data['nnkd'] == '1-RUR-0000-3143488')&(data['mob']==7)].T
# Out:
#                                          186                 866
# nnkd                      1-RUR-0000-3143488  1-RUR-0000-3143488
# mob                                        7                   7
# MOB_term                            0.189189            0.189189
# Credit_TermApr                            37                  37
# curr_del_cap_share_one              0.908143            0.840692
# curr_rep_cap_share_one             0.0918571            0.159308
# bad                                        0                   0
# maxdelay_one                              76                  76
# DaysInCollection_one                      16                  16
# delays_one                                 1                   1
# MA_AGE                                    30                  30
# MA_Gender                                  1                   1
# MA_Education                               2                   2
# ...

# %%
data[data['maxdelay_one']>338].T
# Out:
#                                        16693               16778  \
# nnkd                      1-RUR-0000-3203795  1-RUR-0000-3203795
# mob                                       15                  14
# MOB_term                            0.245902            0.229508
# Credit_TermApr                            61                  61
# curr_del_cap_share_one              0.836293            0.836293
# curr_rep_cap_share_one              0.163707            0.163707
# bad                                        1                   1
# maxdelay_one                             339                 339
# DaysInCollection_one                      32                  32
# delays_one                                 1                   1
# MA_AGE                                    38                  38
# MA_Gender                                  0                   0
# MA_Education                               0                   0
# ...
